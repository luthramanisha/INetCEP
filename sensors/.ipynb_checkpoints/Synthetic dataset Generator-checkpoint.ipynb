# %%
from datetime import datetime
from random import randint
ts = int("0")
s = datetime.utcfromtimestamp(ts).strftime('%H:%M:%S.%f')
gender = ['M','F']
id = 1001
for i in range(0,86399):
    print(s[:-3]+"/"+str(id+i)+"/"+gender[randint(0, 1)]+"/"+str(randint(1, 99)))
# Out:
# 00:00:00.000
# 00:00:00.000/1001/M/19
# 00:00:00.000/1002/F/50
# 00:00:00.000/1003/F/27
# 00:00:00.000/1004/M/83
# 00:00:00.000/1005/F/62
# 00:00:00.000/1006/M/86
# 00:00:00.000/1007/F/92
# 00:00:00.000/1008/M/46
# 00:00:00.000/1009/M/54
# 00:00:00.000/1010/F/81
# 00:00:00.000/1011/F/4
# 00:00:00.000/1012/F/34
# 00:00:00.000/1013/F/2
# 00:00:00.000/1014/M/23
# 00:00:00.000/1015/M/84
# 00:00:00.000/1016/F/71
# 00:00:00.000/1017/M/42
# 00:00:00.000/1018/F/47
# 00:00:00.000/1019/M/76
# 00:00:00.000/1020/M/81
# 00:00:00.000/1021/M/87
# 00:00:00.000/1022/F/13
# 00:00:00.000/1023/F/96
# 00:00:00.000/1024/F/14
# 00:00:00.000/1025/M/30
# 00:00:00.000/1026/F/7
# 00:00:00.000/1027/M/29
# 00:00:00.000/1028/M/15
# 00:00:00.000/1029/F/72
# 00:00:00.000/1030/M/49
# 00:00:00.000/1031/M/18
# 00:00:00.000/1032/F/77
# 00:00:00.000/1033/F/57
# 00:00:00.000/1034/F/60
# 00:00:00.000/1035/F/90
# 00:00:00.000/1036/M/31
# 00:00:00.000/1037/F/75
# 00:00:00.000/1038/M/59
# 00:00:00.000/1039/M/35
# ...
